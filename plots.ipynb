# %% [markdown]
# # Draw plots

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# We have obtained these values during the training process of three classification model

de_hstr_loss = [1.1789, 1.1221, 1.1158, 1.0983, 1.0871, 1.0755, 1.0532, 0.9835, 0.8037, 0.6264, 0.5177, 0.4915, 0.2991, 0.2473, 0.1803]
de_hstr_acc = [0.2621, 0.2661, 0.2638, 0.2897, 0.3299, 0.3321, 0.4192, 0.4857, 0.5817, 0.7478, 0.8223, 0.7638, 0.8978, 0.9129, 0.9446]
de_hstr_val_loss = [1.1861, 1.1534, 1.1346, 1.1188, 1.0993, 1.0756, 1.0307, 0.7920, 0.6562, 0.5675, 0.3461, 0.3986, 0.1929, 0.1421, 0.1164]
de_hstr_val_acc = [0.1613, 0.1270, 0.1260, 0.1260, 0.3498, 0.4335, 0.4970, 0.6270, 0.8901, 0.9183, 0.9012, 0.9698, 0.9486, 0.9617, 0.9597]

rr_hstr_loss = [1.5103, 0.6979, 0.2864, 0.1491, 0.0650, 0.0353, 0.0219, 0.0152, 0.0111, 0.0083, 0.0066, 0.0053, 0.0044, 0.0037, 0.0032]
rr_hstr_acc = [0.3480, 0.6987, 0.9480, 0.9853, 0.9973, 0.9987, 0.9996, 0.9996, 0.9996, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000]
rr_hstr_val_loss = [0.9550, 0.4579, 0.3729, 0.2771, 0.2416, 0.2291, 0.2267, 0.2208, 0.2153, 0.2129, 0.2125, 0.2224, 0.2176, 0.2190, 0.2166]
rr_hstr_val_acc = [0.5110, 0.8390, 0.8890, 0.9040, 0.9080, 0.9100, 0.9080, 0.9090, 0.9130, 0.9140, 0.9140, 0.9040, 0.9040, 0.9050, 0.9080]

t5_hstr_loss = [1.6241, 1.5520, 1.5441, 1.4852, 1.2671, 1.2001, 1.1280, 0.9537, 0.9004, 0.7215, 0.5694, 0.5015, 0.3257, 0.3030, 0.2164]
t5_hstr_acc = [0.2906, 0.2873, 0.3700, 0.3698, 0.3621, 0.4107, 0.4520, 0.4864, 0.5541, 0.6518, 0.7956, 0.8048, 0.8369, 0.8528, 0.9001]
t5_hstr_val_loss = [1.3465, 1.2798, 1.0046, 1.1088, 1.0985, 0.9243, 0.9812, 0.7849, 0.6920, 0.5002, 0.4998, 0.3927, 0.3849, 0.2928, 0.1528]
t5_hstr_val_acc = [0.2167, 0.3062, 0.3065, 0.4783, 0.5698, 0.5420, 0.6070, 0.6151, 0.7534, 0.8094, 0.8213, 0.8740, 0.8215, 0.8864, 0.9132]

# %% [markdown]
# ### Training loss

# %%
plt.plot(rr_hstr_loss, label='Recurrent retention')
plt.plot(t5_hstr_loss, label='T5')
plt.plot(de_hstr_loss, label='DeBERTa')
plt.title('Training loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Training accuracy

# %%
plt.plot(de_hstr_acc, label='DeBERTa')
plt.plot(rr_hstr_acc, label='Recurrent retention')
plt.plot(t5_hstr_acc, label='T5')
plt.title('Training accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Validation loss

# %%
plt.plot(de_hstr_val_loss, label='DeBERTa')
plt.plot(rr_hstr_val_loss, label='Recurrent retention')
plt.plot(t5_hstr_val_loss, label='T5')
plt.title('Validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Validation accuracy

# %%
plt.plot(de_hstr_val_acc, label='DeBERTa')
plt.plot(rr_hstr_val_acc, label='Recurrent retention')
plt.plot(t5_hstr_val_acc, label='T5')
plt.title('Validation accuracy')
plt.legend()
plt.show()
